# %%
import os
import datetime
import json
import rasterio
from itertools import chain
import json

# %%
from pathlib import Path

# %%
files = Path('tif').stem
indexEnd = 10

# %%
list = os.listdir('tif')
cropList = os.listdir('tif/AnnualCrop')
forestList = os.listdir('tif/Forest')
vegetationList = os.listdir('tif/HerbaceousVegetation')
highwayList = os.listdir('tif/Highway')
industrialList = os.listdir('tif/Industrial')
pastureList = os.listdir('tif/Pasture')
permanentcropList = os.listdir('tif/PermanentCrop')
residentalList = os.listdir('tif/Residential')
riverList = os.listdir('tif/River')
lakeList = os.listdir('tif/SeaLake')

# %%
print(list)
# Out:
# ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']

# %%
date = datetime.datetime.now()

# %%
print(date)
# Out:
# 2022-05-09 16:52:24.687139

# %%
date_year = date.year

# %%
print(date_year)
# Out:
# 2022

# %%
count=len(cropList)
print(count)

print(list)
# Out:
# 12
# ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']

# %%
annualCrop = []
cropName = []
for x in cropList[0:indexEnd]:
     print(x)
     value = rasterio.open('tif/AnnualCrop/' + x)
     cropName.append(x)   
     annualCrop.append(value) 
print(annualCrop)
    
forest = []
forestName = []
for x in forestList[0:indexEnd]:  
    value = rasterio.open('tif/Forest/' + x)
    forestName.append(x)   
    forest.append(value)

vegetation = []
vegetationName = []
for x in vegetationList[0:indexEnd]:  
    value = rasterio.open('tif/HerbaceousVegetation/' + x)
    vegetationName.append(x)   
    vegetation.append(value)

industrial = []
industrialName = []
for x in industrialList[0:indexEnd]:  
    value = rasterio.open('tif/Industrial/' + x)
    industrialName.append(x)   
    industrial.append(value)    
    
pasture = []
pastureName = []
for x in pastureList[0:indexEnd]:  
    value = rasterio.open('tif/Pasture/' + x)
    pastureName.append(x)   
    pasture.append(value)
    
permanentCrop = []
permanentCropName = []
for x in permanentcropList[0:indexEnd]:  
    value = rasterio.open('tif/PermanentCrop/' + x)
    permanentCropName.append(x)   
    permanentCrop.append(value)

residential = []
residentialName = []
for x in residentalList[0:indexEnd]:  
    value = rasterio.open('tif/Residential/' + x)
    residentialName.append(x)   
    residential.append(value)

river = []
riverName = []
for x in riverList[0:indexEnd]:  
    value = rasterio.open('tif/River/' + x)
    riverName.append(x)   
    river.append(value)

lake = []
lakeName = []
for x in lakeList[0:indexEnd]:  
    value = rasterio.open('tif/SeaLake/' + x)
    lakeName.append(x)   
    lake.append(value)
 
highway = []
highwayName = []
for x in highwayList[0:indexEnd]:  
    value = rasterio.open('tif/Highway/' + x)
    highwayName.append(x)   
    highway.append(value)
# Out:
# AnnualCrop_1.tif
# AnnualCrop_10.tif
# AnnualCrop_11.tif
# AnnualCrop_12.tif
# AnnualCrop_2.tif
# AnnualCrop_3.tif
# AnnualCrop_4.tif
# AnnualCrop_5.tif
# AnnualCrop_6.tif
# AnnualCrop_7.tif
# [<open DatasetReader name='tif/AnnualCrop/AnnualCrop_1.tif' mode='r'>, <open DatasetReader name='tif/AnnualCrop/AnnualCrop_10.tif' mode='r'>, <open DatasetReader name='tif/AnnualCrop/AnnualCrop_11.tif' mode='r'>, <open DatasetReader name='tif/AnnualCrop/AnnualCrop_12.tif' mode='r'>, <open DatasetReader name='tif/AnnualCrop/AnnualCrop_2.tif' mode='r'>, <open DatasetReader name='tif/AnnualCrop/AnnualCrop_3.tif' mode='r'>, <open DatasetReader name='tif/AnnualCrop/AnnualCrop_4.tif' mode='r'>, <open DatasetReader name='tif/AnnualCrop/AnnualCrop_5.tif' mode='r'>, <open DatasetReader name='tif/AnnualCrop/AnnualCrop_6.tif' mode='r'>, <open DatasetReader name='tif/AnnualCrop/AnnualCrop_7.tif' mode='r'>]

# %%
annual_bound = []
for x in annualCrop:     
     value = x.bounds
     annual_bound.append(value)  

forest_bound = []
for x in forest:     
     value = x.bounds
     forest_bound.append(value)

vegetation_bound = []
for x in vegetation:     
     value = x.bounds
     vegetation_bound.append(value) 

industrial_bound = []
for x in industrial:     
     value = x.bounds
     industrial_bound.append(value)

pasture_bound = []
for x in pasture:     
     value = x.bounds
     pasture_bound.append(value)
 
permanentCrop_bound = []
for x in permanentCrop:     
     value = x.bounds
     permanentCrop_bound.append(value)

residential_bound = []
for x in residential:     
     value = x.bounds
     residential_bound.append(value)
 
river_bound = []
for x in river:     
     value = x.bounds
     river_bound.append(value)

seaLake_bound = []
for x in lake:     
     value = x.bounds
     seaLake_bound.append(value)
 
highway_bound = []
for x in highway:     
     value = x.bounds
     highway_bound.append(value)

# %%
bound_list = [annual_bound,forest_bound,vegetation_bound,highway_bound,industrial_bound,pasture_bound,permanentCrop_bound,residential_bound,river_bound,seaLake_bound]

# %%
cropTuple = []
for index, item in enumerate(annual_bound):    
        value = {
            "name":cropName[index],
            "bound":item,
            "label" : list[0],
            "date": date_year
        }
        cropTuple.append(value)

forestTuple = []
for index, item in enumerate(forest_bound):
        value = {
            "name":forestName[index],
            "bound":item,
            "label" : list[1],
            "date": date_year
        }
        forestTuple.append(value)

vegetationTuple = []
for index, item in enumerate(vegetation_bound):
        value = {
            "name":vegetationName[index],
            "bound":item,
            "label" : list[2],
            "date": date_year
        }
        vegetationTuple.append(value)

highwayTuple = []
for index, item in enumerate(highway_bound):
        value = {
            "name":highwayName[index],
            "bound":item,
            "label" : list[3],
            "date": date_year
        }
        highwayTuple.append(value)
     
industrialTuple = []
for index, item in enumerate(industrial_bound):
        value = {
            "name":industrialName[index],
            "bound":item,
            "label" : list[4],
            "date": date_year
        }
        industrialTuple.append(value)
        
pastureTuple = []
for index, item in enumerate(pasture_bound):
        value = {
            "name":pastureName[index],
            "bound":item,
            "label" : list[5],
            "date": date_year
        }
        pastureTuple.append(value)
        
permanentCropTuple = []
for index, item in enumerate(permanentCrop_bound):
        value = {
            "name":permanentCropName[index],
            "bound":item,
            "label" : list[6],
            "date": date_year
        }
        permanentCropTuple.append(value)
 
residentialTuple = []
for index, item in enumerate(residential_bound):
        value = {
            "name":residentialName[index],
            "bound":item,
            "label" : list[7],
            "date": date_year
            
        }
        residentialTuple.append(value)
 
riverTuple = []
for index, item in enumerate(river_bound):
        value = {
            "name":riverName[index],
            "bound":item,
            "label" : list[8],
            "date": date_year
        }
        riverTuple.append(value)

seaLakeTuple = []
for index, item in enumerate(seaLake_bound):
        value = {
            "name":lakeName[index],
            "bound":item,
            "label" : list[9],
            "date": date_year
        }
        seaLakeTuple.append(value)

# %%
data = []

data.extend(cropTuple)
data.extend(forestTuple)
data.extend(vegetationTuple)
data.extend(highwayTuple)
data.extend(industrialTuple)
data.extend(pastureTuple)
data.extend(permanentCropTuple)
data.extend(residentialTuple)
data.extend(riverTuple)
data.extend(seaLakeTuple)

europa= json.dumps(data, indent=3)

print(europa)
# Out:
# [
#    {
#       "name": "AnnualCrop_1.tif",
#       "bound": [
#          624602.2348443292,
#          4876646.411998601,
#          625242.6000851066,
#          4877286.033637
#       ],
#       "label": "AnnualCrop",
#       "date": 2022
#    },
#    {
#       "name": "AnnualCrop_10.tif",
#       "bound": [
#          600895.0021822372,
#          4326629.904506601,
#          601535.0190696092,
#          4327269.855440698
#       ],
#       "label": "AnnualCrop",
#       "date": 2022
#    },
#    {
#       "name": "AnnualCrop_11.tif",
#       "bound": [
#          499983.561707,
#          5572656.981119087,
#          500624.15243888024,
#          5573298.11984326
#       ],
#       "label": "AnnualCrop",
#       "date": 2022
#    },
#    {
#       "name": "AnnualCrop_12.tif",
#       "bound": [
#          577311.3713245124,
#          4829760.81485602,
#          577950.9735523309,
#          4830400.12070767
#       ],
#       "label": "AnnualCrop",
#       "date": 2022
#    },
#    {
#       "name": "AnnualCrop_2.tif",
#       "bound": [
#          689460.0611906666,
#          5833703.585256051,
#          690098.7473491076,
#          5834343.078539004
#       ],
#       "label": "AnnualCrop",
#       "date": 2022
#    },
#    {
#       "name": "AnnualCrop_3.tif",
#       "bound": [
#          590396.5856479653,
#          5424051.305157872,
#          591036.336018,
#          5424691.679311476
#       ],
#       "label": "AnnualCrop",
#       "date": 2022
#    },
#    {
#       "name": "AnnualCrop_4.tif",
#       "bound": [
#          511030.86427903076,
#          5390549.583700793,
#          511670.4539942459,
#          5391188.777069603
#       ],
#       "label": "AnnualCrop",
#       "date": 2022
#    },
#    {
#       "name": "AnnualCrop_5.tif",
#       "bound": [
#          696303.6892303755,
#          5923678.293865927,
#          696944.8250154218,
#          5924318.046814075
#       ],
#       "label": "AnnualCrop",
#       "date": 2022
#    },
#    {
#       "name": "AnnualCrop_6.tif",
#       "bound": [
#          677244.8383925555,
#          5127286.127215969,
#          677885.6312871333,
#          5127926.58714479
#       ],
#       "label": "AnnualCrop",
#       "date": 2022
#    },
#    {
#       "name": "AnnualCrop_7.tif",
#       "bound": [
#          305037.0218271271,
#          5418803.617906136,
#          305677.64121629833,
#          5419443.210926396
#       ],
#       "label": "AnnualCrop",
#       "date": 2022
#    },
#    {
#       "name": "Forest_1.tif",
#       "bound": [
#          533043.6787387297,
#          5567151.910523886,
#          533684.0112932943,
#          5567792.427645094
#       ],
#       "label": "Forest",
#       "date": 2022
#    },
#    {
#       "name": "Forest_10.tif",
#       "bound": [
#          548646.972884193,
#          5530042.697442983,
#          549286.3177350906,
#          5530683.958191891
#       ],
#       "label": "Forest",
#       "date": 2022
#    },
#    {
#       "name": "Forest_11.tif",
#       "bound": [
#          507628.8954786842,
#          5524352.162496931,
#          508268.9984260526,
#          5524992.600523965
#       ],
#       "label": "Forest",
#       "date": 2022
#    },
#    {
#       "name": "Forest_12.tif",
#       "bound": [
#          725587.3062166426,
#          4738794.672336087,
#          726227.374657639,
#          4739434.894814927
#       ],
#       "label": "Forest",
#       "date": 2022
#    },
#    {
#       "name": "Forest_2.tif",
#       "bound": [
#          558176.7257078927,
#          4751962.486491104,
#          558816.9136938486,
#          4752602.472653375
#       ],
#       "label": "Forest",
#       "date": 2022
#    },
#    {
#       "name": "Forest_3.tif",
#       "bound": [
#          729841.7500830976,
#          4696865.658239617,
#          730481.8006245653,
#          4697505.872781475
#       ],
#       "label": "Forest",
#       "date": 2022
#    },
#    {
#       "name": "Forest_4.tif",
#       "bound": [
#          487303.46812254656,
#          5614594.667901803,
#          487943.04359703104,
#          5615234.092041694
#       ],
#       "label": "Forest",
#       "date": 2022
#    },
#    {
#       "name": "Forest_5.tif",
#       "bound": [
#          521269.9910867697,
#          5547426.401546643,
#          521910.0041082514,
#          5548066.901215455
#       ],
#       "label": "Forest",
#       "date": 2022
#    },
#    {
#       "name": "Forest_6.tif",
#       "bound": [
#          492478.7025848493,
#          5569847.871244066,
#          493118.9312134521,
#          5570488.097776333
#       ],
#       "label": "Forest",
#       "date": 2022
#    },
#    {
#       "name": "Forest_7.tif",
#       "bound": [
#          643761.4056140125,
#          5192939.705830775,
#          644401.5795419903,
#          5193579.707861146
#       ],
#       "label": "Forest",
#       "date": 2022
#    },
#    {
#       "name": "HerbaceousVegetation_1.tif",
#       "bound": [
#          533701.6159570202,
#          5945782.413208171,
#          534342.2964867532,
#          5946422.5058129765
#       ],
#       "label": "HerbaceousVegetation",
#       "date": 2022
#    },
#    {
#       "name": "HerbaceousVegetation_10.tif",
#       "bound": [
#          655570.7620123917,
#          5224905.480494862,
#          656210.8311476918,
#          5225545.570952241
#       ],
#       "label": "HerbaceousVegetation",
#       "date": 2022
#    },
#    {
#       "name": "HerbaceousVegetation_11.tif",
#       "bound": [
#          664667.8907157432,
#          4625281.892776991,
#          665308.2224847245,
#          4625921.470540823
#       ],
#       "label": "HerbaceousVegetation",
#       "date": 2022
#    },
#    {
#       "name": "HerbaceousVegetation_12.tif",
#       "bound": [
#          600426.7688011735,
#          4103650.531007166,
#          601066.5982426675,
#          4104290.505361142
#       ],
#       "label": "HerbaceousVegetation",
#       "date": 2022
#    },
#    {
#       "name": "HerbaceousVegetation_13.tif",
#       "bound": [
#          793410.0688345509,
#          4176488.1451944904,
#          794050.0910526884,
#          4177128.4348377134
#       ],
#       "label": "HerbaceousVegetation",
#       "date": 2022
#    },
#    {
#       "name": "HerbaceousVegetation_14.tif",
#       "bound": [
#          481449.4647200508,
#          3883036.7262559235,
#          482089.4048820367,
#          3883676.83421909
#       ],
#       "label": "HerbaceousVegetation",
#       "date": 2022
#    },
#    {
#       "name": "HerbaceousVegetation_15.tif",
#       "bound": [
#          360538.20111341437,
#          4052607.6001618626,
#          361178.31687666534,
#          4053247.393017549
#       ],
#       "label": "HerbaceousVegetation",
#       "date": 2022
#    },
#    {
#       "name": "HerbaceousVegetation_16.tif",
#       "bound": [
#          533988.4531712541,
#          5983190.372452035,
#          534628.3347322884,
#          5983830.619929548
#       ],
#       "label": "HerbaceousVegetation",
#       "date": 2022
#    },
#    {
#       "name": "HerbaceousVegetation_2.tif",
#       "bound": [
#          616288.2970777557,
#          4313637.301910909,
#          616928.4149757747,
#          4314277.314187272
#       ],
#       "label": "HerbaceousVegetation",
#       "date": 2022
#    },
#    {
#       "name": "HerbaceousVegetation_3.tif",
#       "bound": [
#          578715.7608054391,
#          5930075.8159294445,
#          579356.6460095637,
#          5930716.1082316665
#       ],
#       "label": "HerbaceousVegetation",
#       "date": 2022
#    },
#    {
#       "name": "Highway_1.tif",
#       "bound": [
#          376456.862268,
#          4823441.705285814,
#          377094.74541228235,
#          4824080.82987
#       ],
#       "label": "Highway",
#       "date": 2022
#    },
#    {
#       "name": "Highway_10.tif",
#       "bound": [
#          383078.174828,
#          6574928.874290769,
#          383719.9459617412,
#          6575567.53114
#       ],
#       "label": "Highway",
#       "date": 2022
#    },
#    {
#       "name": "Highway_11.tif",
#       "bound": [
#          435220.937878,
#          4686897.6643574415,
#          435862.2052434468,
#          4687538.21187
#       ],
#       "label": "Highway",
#       "date": 2022
#    },
#    {
#       "name": "Highway_12.tif",
#       "bound": [
#          568377.114326,
#          6707206.222689484,
#          569016.8588831048,
#          6707849.37624
#       ],
#       "label": "Highway",
#       "date": 2022
#    },
#    {
#       "name": "Highway_13.tif",
#       "bound": [
#          786071.141382,
#          4149700.8295744304,
#          786712.753121759,
#          4150340.69946
#       ],
#       "label": "Highway",
#       "date": 2022
#    },
#    {
#       "name": "Highway_14.tif",
#       "bound": [
#          698233.096569,
#          4813795.318225675,
#          698875.9578088298,
#          4814435.07647
#       ],
#       "label": "Highway",
#       "date": 2022
#    },
#    {
#       "name": "Highway_15.tif",
#       "bound": [
#          506434.131659,
#          5408889.087914267,
#          507074.4371012626,
#          5409530.53271
#       ],
#       "label": "Highway",
#       "date": 2022
#    },
#    {
#       "name": "Highway_16.tif",
#       "bound": [
#          370314.994784,
#          6222577.298127177,
#          370958.06741750723,
#          6223214.86109
#       ],
#       "label": "Highway",
#       "date": 2022
#    },
#    {
#       "name": "Highway_2.tif",
#       "bound": [
#          470508.704307,
#          5553512.1117258975,
#          471151.19453228,
#          5554150.91893
#       ],
#       "label": "Highway",
#       "date": 2022
#    },
#    {
#       "name": "Highway_3.tif",
#       "bound": [
#          367910.518208,
#          5393784.5008473685,
#          368549.7456738969,
#          5394427.03198
#       ],
#       "label": "Highway",
#       "date": 2022
#    },
#    {
#       "name": "Industrial_1.tif",
#       "bound": [
#          323455.648169,
#          5506434.108220269,
#          324095.84228732967,
#          5507072.615229128
#       ],
#       "label": "Industrial",
#       "date": 2022
#    },
#    {
#       "name": "Industrial_10.tif",
#       "bound": [
#          472739.722609,
#          5535108.833957013,
#          473383.5097893733,
#          5535750.37457
#       ],
#       "label": "Industrial",
#       "date": 2022
#    },
#    {
#       "name": "Industrial_11.tif",
#       "bound": [
#          575919.316293,
#          5818612.251288849,
#          576559.9760180612,
#          5819251.50668
#       ],
#       "label": "Industrial",
#       "date": 2022
#    },
#    {
#       "name": "Industrial_12.tif",
#       "bound": [
#          370342.00890391256,
#          4822503.833637324,
#          370982.43396918033,
#          4823144.33159338
#       ],
#       "label": "Industrial",
#       "date": 2022
#    },
#    {
#       "name": "Industrial_13.tif",
#       "bound": [
#          558158.754241,
#          6703833.483672222,
#          558801.3265132318,
#          6704469.06673
#       ],
#       "label": "Industrial",
#       "date": 2022
#    },
#    {
#       "name": "Industrial_14.tif",
#       "bound": [
#          676449.290783,
#          5406486.538484445,
#          677090.5826469157,
#          5407128.0454
#       ],
#       "label": "Industrial",
#       "date": 2022
#    },
#    {
#       "name": "Industrial_15.tif",
#       "bound": [
#          523351.9125131071,
#          5952487.151218632,
#          523990.5338557357,
#          5953126.71522
#       ],
#       "label": "Industrial",
#       "date": 2022
#    },
#    {
#       "name": "Industrial_16.tif",
#       "bound": [
#          442345.378515,
#          4519657.000844348,
#          442986.02716908,
#          4520297.74554
#       ],
#       "label": "Industrial",
#       "date": 2022
#    },
#    {
#       "name": "Industrial_2.tif",
#       "bound": [
#          609970.162294,
#          5673997.227690459,
#          610612.8233885306,
#          5674634.42285
#       ],
#       "label": "Industrial",
#       "date": 2022
#    },
#    {
#       "name": "Industrial_3.tif",
#       "bound": [
#          480224.5526031968,
#          5604303.284185413,
#          480864.33544745215,
#          5604945.38859203
#       ],
#       "label": "Industrial",
#       "date": 2022
#    },
#    {
#       "name": "Pasture_1.tif",
#       "bound": [
#          546010.2532068333,
#          5583198.797042905,
#          546649.3104236538,
#          5583837.761680224
#       ],
#       "label": "Pasture",
#       "date": 2022
#    },
#    {
#       "name": "Pasture_10.tif",
#       "bound": [
#          591060.523566,
#          5103504.580875636,
#          591701.0183580437,
#          5104146.289667878
#       ],
#       "label": "Pasture",
#       "date": 2022
#    },
#    {
#       "name": "Pasture_11.tif",
#       "bound": [
#          735182.809512,
#          5051076.782543774,
#          735821.0835769639,
#          5051716.88306
#       ],
#       "label": "Pasture",
#       "date": 2022
#    },
#    {
#       "name": "Pasture_12.tif",
#       "bound": [
#          504745.12373,
#          5884303.811075454,
#          505385.1048831694,
#          5884944.631245151
#       ],
#       "label": "Pasture",
#       "date": 2022
#    },
#    {
#       "name": "Pasture_2.tif",
#       "bound": [
#          445560.389192,
#          6173950.80322,
#          446200.436408,
#          6174590.06722
#       ],
#       "label": "Pasture",
#       "date": 2022
#    },
#    {
#       "name": "Pasture_3.tif",
#       "bound": [
#          695768.6828827531,
#          5638650.3431836795,
#          696408.5954744766,
#          5639291.111018133
#       ],
#       "label": "Pasture",
#       "date": 2022
#    },
#    {
#       "name": "Pasture_4.tif",
#       "bound": [
#          526349.472737,
#          5969803.647286667,
#          526986.7105322654,
#          5970444.30108
#       ],
#       "label": "Pasture",
#       "date": 2022
#    },
#    {
#       "name": "Pasture_5.tif",
#       "bound": [
#          491424.4555814926,
#          6183513.619837129,
#          492065.07889766997,
#          6184153.828369406
#       ],
#       "label": "Pasture",
#       "date": 2022
#    },
#    {
#       "name": "Pasture_6.tif",
#       "bound": [
#          456738.975724,
#          6177477.179687114,
#          457380.11236308573,
#          6178117.17906
#       ],
#       "label": "Pasture",
#       "date": 2022
#    },
#    {
#       "name": "Pasture_7.tif",
#       "bound": [
#          505048.32763230795,
#          5637995.882951536,
#          505688.1194151372,
#          5638635.321905256
#       ],
#       "label": "Pasture",
#       "date": 2022
#    },
#    {
#       "name": "PermanentCrop_1.tif",
#       "bound": [
#          631913.2224787272,
#          5180323.682442637,
#          632552.3582647971,
#          5180965.47388
#       ],
#       "label": "PermanentCrop",
#       "date": 2022
#    },
#    {
#       "name": "PermanentCrop_10.tif",
#       "bound": [
#          628648.6754658722,
#          5220711.331789714,
#          629287.1090499925,
#          5221352.88496
#       ],
#       "label": "PermanentCrop",
#       "date": 2022
#    },
#    {
#       "name": "PermanentCrop_11.tif",
#       "bound": [
#          780604.5994852113,
#          4142663.6655186256,
#          781245.1184677153,
#          4143304.7982746563
#       ],
#       "label": "PermanentCrop",
#       "date": 2022
#    },
#    {
#       "name": "PermanentCrop_12.tif",
#       "bound": [
#          778279.9481927555,
#          4152187.947199532,
#          778920.5209826685,
#          4152828.27848
#       ],
#       "label": "PermanentCrop",
#       "date": 2022
#    },
#    {
#       "name": "PermanentCrop_2.tif",
#       "bound": [
#          782559.2906439706,
#          4675998.656478506,
#          783197.5745784647,
#          4676638.203438174
#       ],
#       "label": "PermanentCrop",
#       "date": 2022
#    },
#    {
#       "name": "PermanentCrop_3.tif",
#       "bound": [
#          322328.76137245615,
#          3898267.0050182934,
#          322968.18908490526,
#          3898906.3510433263
#       ],
#       "label": "PermanentCrop",
#       "date": 2022
#    },
#    {
#       "name": "PermanentCrop_4.tif",
#       "bound": [
#          630994.8467441367,
#          4861831.558300889,
#          631633.5377453789,
#          4862468.63402
#       ],
#       "label": "PermanentCrop",
#       "date": 2022
#    },
#    {
#       "name": "PermanentCrop_5.tif",
#       "bound": [
#          602687.859219,
#          4573177.388876666,
#          603328.0410113368,
#          4573818.75869
#       ],
#       "label": "PermanentCrop",
#       "date": 2022
#    },
#    {
#       "name": "PermanentCrop_6.tif",
#       "bound": [
#          524480.6300911912,
#          4813593.638069788,
#          525122.1115377794,
#          4814233.306470513
#       ],
#       "label": "PermanentCrop",
#       "date": 2022
#    },
#    {
#       "name": "PermanentCrop_7.tif",
#       "bound": [
#          752845.6224685031,
#          4789184.519091406,
#          753485.7756160754,
#          4789824.135846406
#       ],
#       "label": "PermanentCrop",
#       "date": 2022
#    },
#    {
#       "name": "Residential_1.tif",
#       "bound": [
#          612091.140535,
#          5775054.591520323,
#          612729.9480746303,
#          5775693.039644194
#       ],
#       "label": "Residential",
#       "date": 2022
#    },
#    {
#       "name": "Residential_10.tif",
#       "bound": [
#          557822.157079,
#          6332104.215511807,
#          558464.2397924545,
#          6332747.43236
#       ],
#       "label": "Residential",
#       "date": 2022
#    },
#    {
#       "name": "Residential_11.tif",
#       "bound": [
#          685226.74687,
#          4739306.343428987,
#          685864.0281932207,
#          4739949.17103
#       ],
#       "label": "Residential",
#       "date": 2022
#    },
#    {
#       "name": "Residential_12.tif",
#       "bound": [
#          422110.13357824465,
#          4476231.696894818,
#          422750.21951768553,
#          4476871.072998796
#       ],
#       "label": "Residential",
#       "date": 2022
#    },
#    {
#       "name": "Residential_13.tif",
#       "bound": [
#          597474.215971,
#          4799080.584574247,
#          598115.2029663267,
#          4799723.52128
#       ],
#       "label": "Residential",
#       "date": 2022
#    },
#    {
#       "name": "Residential_14.tif",
#       "bound": [
#          648370.048955,
#          5109667.275068506,
#          649007.9299177234,
#          5110309.46584
#       ],
#       "label": "Residential",
#       "date": 2022
#    },
#    {
#       "name": "Residential_15.tif",
#       "bound": [
#          505904.721999538,
#          5070805.539735685,
#          506545.03448423365,
#          5071447.6769806165
#       ],
#       "label": "Residential",
#       "date": 2022
#    },
#    {
#       "name": "Residential_16.tif",
#       "bound": [
#          365120.6453688,
#          4821584.357109442,
#          365759.85176623997,
#          4822225.32724
#       ],
#       "label": "Residential",
#       "date": 2022
#    },
#    {
#       "name": "Residential_17.tif",
#       "bound": [
#          560261.902984,
#          5525661.388336303,
#          560902.2853777391,
#          5526302.59934
#       ],
#       "label": "Residential",
#       "date": 2022
#    },
#    {
#       "name": "Residential_18.tif",
#       "bound": [
#          608208.9417200403,
#          4857063.2370391805,
#          608849.4070950755,
#          4857703.330542131
#       ],
#       "label": "Residential",
#       "date": 2022
#    },
#    {
#       "name": "River_1.tif",
#       "bound": [
#          314531.0944185345,
#          5501810.29530199,
#          315171.0762017069,
#          5502450.401013539
#       ],
#       "label": "River",
#       "date": 2022
#    },
#    {
#       "name": "River_10.tif",
#       "bound": [
#          662314.7495032703,
#          5736370.63475071,
#          662955.0482051081,
#          5737010.511655401
#       ],
#       "label": "River",
#       "date": 2022
#    },
#    {
#       "name": "River_11.tif",
#       "bound": [
#          357469.0494552136,
#          5998875.566813601,
#          358108.8099653495,
#          5999515.979390318
#       ],
#       "label": "River",
#       "date": 2022
#    },
#    {
#       "name": "River_12.tif",
#       "bound": [
#          575160.1328984887,
#          5754272.783607009,
#          575800.1294810718,
#          5754912.656702131
#       ],
#       "label": "River",
#       "date": 2022
#    },
#    {
#       "name": "River_13.tif",
#       "bound": [
#          541648.8729026288,
#          5703042.45277516,
#          542290.5424810942,
#          5703683.189281499
#       ],
#       "label": "River",
#       "date": 2022
#    },
#    {
#       "name": "River_14.tif",
#       "bound": [
#          583610.0877779077,
#          5753622.912494775,
#          584250.0843604909,
#          5754262.785589897
#       ],
#       "label": "River",
#       "date": 2022
#    },
#    {
#       "name": "River_15.tif",
#       "bound": [
#          766004.4019173022,
#          5004325.206126713,
#          766643.5297658201,
#          5004965.467429091
#       ],
#       "label": "River",
#       "date": 2022
#    },
#    {
#       "name": "River_16.tif",
#       "bound": [
#          492008.508977,
#          5874461.487474126,
#          492648.3118868555,
#          5875101.21111
#       ],
#       "label": "River",
#       "date": 2022
#    },
#    {
#       "name": "River_2.tif",
#       "bound": [
#          648265.1952947535,
#          5335839.430209732,
#          648904.9976160584,
#          5336479.634437341
#       ],
#       "label": "River",
#       "date": 2022
#    },
#    {
#       "name": "River_3.tif",
#       "bound": [
#          474641.2497334305,
#          6190438.078262784,
#          475281.33747883735,
#          6191077.9414809095
#       ],
#       "label": "River",
#       "date": 2022
#    },
#    {
#       "name": "SeaLake_1.tif",
#       "bound": [
#          547713.6708782589,
#          6425702.312785538,
#          548353.8421163161,
#          6426342.401814095
#       ],
#       "label": "SeaLake",
#       "date": 2022
#    },
#    {
#       "name": "SeaLake_10.tif",
#       "bound": [
#          589969.3635404648,
#          6002714.94526566,
#          590609.0458186489,
#          6003354.9161919495
#       ],
#       "label": "SeaLake",
#       "date": 2022
#    },
#    {
#       "name": "SeaLake_11.tif",
#       "bound": [
#          455217.59372077446,
#          5817217.49334326,
#          455858.25089764403,
#          5817856.977767608
#       ],
#       "label": "SeaLake",
#       "date": 2022
#    },
#    {
#       "name": "SeaLake_12.tif",
#       "bound": [
#          498852.9246250253,
#          6963145.486818577,
#          499492.6096695823,
#          6963785.639209502
#       ],
#       "label": "SeaLake",
#       "date": 2022
#    },
#    {
#       "name": "SeaLake_13.tif",
#       "bound": [
#          420193.0754147196,
#          6782480.089574433,
#          420833.2060986408,
#          6783119.947938745
#       ],
#       "label": "SeaLake",
#       "date": 2022
#    },
#    {
#       "name": "SeaLake_14.tif",
#       "bound": [
#          549108.3174720089,
#          6995093.247502483,
#          549747.9305309657,
#          6995733.125597931
#       ],
#       "label": "SeaLake",
#       "date": 2022
#    },
#    {
#       "name": "SeaLake_15.tif",
#       "bound": [
#          744595.653178,
#          4092659.9980461467,
#          745237.0005186511,
#          4093302.40299
#       ],
#       "label": "SeaLake",
#       "date": 2022
#    },
#    {
#       "name": "SeaLake_16.tif",
#       "bound": [
#          768935.882207296,
#          4664982.248580732,
#          769575.7812980328,
#          4665622.341557309
#       ],
#       "label": "SeaLake",
#       "date": 2022
#    },
#    {
#       "name": "SeaLake_2.tif",
#       "bound": [
#          634546.7884836885,
#          5308366.106641765,
#          635186.5444274032,
#          5309006.346688824
#       ],
#       "label": "SeaLake",
#       "date": 2022
#    },
#    {
#       "name": "SeaLake_3.tif",
#       "bound": [
#          582716.9725641885,
#          5735947.786636054,
#          583357.0847012927,
#          5736587.878533275
#       ],
#       "label": "SeaLake",
#       "date": 2022
#    }
# ]

# %%
with open("./ProcessedImageJson.json", "w") as f:    
      f.write( europa )
